# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Ok lets take a look at some of the data for this week that was supposed to be big.  First I will define a small function that returns the size of a dataframe in megabytes

# %%
def size_it (df):
    total=0
    for i in range(len(data.memory_usage())):
        total=total+data.memory_usage()[i]
    size=total/(2**20)
    print("%.2f Megabytes" % size)

# %% [markdown]
# Read in the 1987 file:

# %%
data=pd.read_csv("./Data/1987.csv")

# %%
size_it(data)
# Out:
# 290.24 Megabytes

# %%
data.memory_usage()
# Out:
# Index                      80
# Year                 10494608
# Month                10494608
# DayofMonth           10494608
# DayOfWeek            10494608
# DepTime              10494608
# CRSDepTime           10494608
# ArrTime              10494608
# CRSArrTime           10494608
# UniqueCarrier        10494608
# FlightNum            10494608
# TailNum              10494608
# ActualElapsedTime    10494608
# CRSElapsedTime       10494608
# AirTime              10494608
# ArrDelay             10494608
# DepDelay             10494608
# Origin               10494608
# Dest                 10494608
# Distance             10494608
# TaxiIn               10494608
# TaxiOut              10494608
# Cancelled            10494608
# CancellationCode     10494608
# Diverted             10494608
# CarrierDelay         10494608
# WeatherDelay         10494608
# NASDelay             10494608
# SecurityDelay        10494608
# LateAircraftDelay    10494608
# dtype: int64

# %% [markdown]
# Lets look at the data (Always look at the data)

# %%
data.head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  1987     10          14          3    741.0         730    912.0
# 1  1987     10          15          4    729.0         730    903.0
# 2  1987     10          17          6    741.0         730    918.0
# 3  1987     10          18          7    729.0         730    847.0
# 4  1987     10          19          1    749.0         730    922.0
#
#    CRSArrTime UniqueCarrier  FlightNum        ...          TaxiIn  TaxiOut  \
# 0         849            PS       1451        ...             NaN      NaN
# 1         849            PS       1451        ...             NaN      NaN
# 2         849            PS       1451        ...             NaN      NaN
# 3         849            PS       1451        ...             NaN      NaN
# 4         849            PS       1451        ...             NaN      NaN
#
#    Cancelled  CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# 0          0               NaN         0           NaN          NaN      NaN
# 1          0               NaN         0           NaN          NaN      NaN
# 2          0               NaN         0           NaN          NaN      NaN
# 3          0               NaN         0           NaN          NaN      NaN
# 4          0               NaN         0           NaN          NaN      NaN
#
#    SecurityDelay  LateAircraftDelay
# 0            NaN                NaN
# 1            NaN                NaN
# 2            NaN                NaN
# 3            NaN                NaN
# 4            NaN                NaN
#
# [5 rows x 29 columns]

# %%
data.iloc[:,0:10].describe()
# Out:
#             Year         Month    DayofMonth     DayOfWeek       DepTime  \
# count  1311826.0  1.311826e+06  1.311826e+06  1.311826e+06  1.292141e+06
# mean      1987.0  1.099374e+01  1.571761e+01  3.949043e+00  1.369276e+03
# std          0.0  8.232012e-01  8.835640e+00  1.986290e+00  4.787183e+02
# min       1987.0  1.000000e+01  1.000000e+00  1.000000e+00  1.000000e+00
# 25%       1987.0  1.000000e+01  8.000000e+00  2.000000e+00  9.460000e+02
# 50%       1987.0  1.100000e+01  1.600000e+01  4.000000e+00  1.345000e+03
# 75%       1987.0  1.200000e+01  2.300000e+01  6.000000e+00  1.750000e+03
# max       1987.0  1.200000e+01  3.100000e+01  7.000000e+00  2.400000e+03
#
#          CRSDepTime       ArrTime    CRSArrTime     FlightNum
# count  1.311826e+06  1.288326e+06  1.311826e+06  1.311826e+06
# mean   1.361131e+03  1.493152e+03  1.491052e+03  6.701427e+02
# std    4.719701e+02  4.987503e+02  4.868002e+02  5.145510e+02
# min    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    9.400000e+02  1.117000e+03  1.115000e+03  2.910000e+02
# 50%    1.338000e+03  1.521000e+03  1.519000e+03  5.600000e+02
# 75%    1.742000e+03  1.918000e+03  1.912000e+03  8.940000e+02
# max    2.359000e+03  2.400000e+03  2.400000e+03  6.282000e+03

# %%
data.iloc[:,10:20].describe()
# Out:
#        TailNum  ActualElapsedTime  CRSElapsedTime  AirTime      ArrDelay  \
# count      0.0       1.288326e+06    1.311826e+06      0.0  1.288326e+06
# mean       NaN       1.021790e+02    1.006191e+02      NaN  9.446699e+00
# std        NaN       6.182632e+01    6.123219e+01      NaN  2.582553e+01
# min        NaN      -5.150000e+02   -4.000000e+01      NaN -1.302000e+03
# 25%        NaN       6.000000e+01    6.000000e+01      NaN -3.000000e+00
# 50%        NaN       8.300000e+01    8.000000e+01      NaN  4.000000e+00
# 75%        NaN       1.290000e+02    1.280000e+02      NaN  1.400000e+01
# max        NaN       1.654000e+03    1.555000e+03      NaN  1.033000e+03
#
#            DepDelay      Distance  TaxiIn
# count  1.292141e+06  1.310811e+06     0.0
# mean   8.063638e+00  5.912441e+02     NaN
# std    2.402479e+01  4.981206e+02     NaN
# min   -1.345000e+03  0.000000e+00     NaN
# 25%    0.000000e+00  2.470000e+02     NaN
# 50%    0.000000e+00  4.160000e+02     NaN
# 75%    8.000000e+00  7.870000e+02     NaN
# max    1.439000e+03  4.983000e+03     NaN

# %%
data.iloc[:,20:].describe()
# Out:
#        TaxiOut     Cancelled  CancellationCode      Diverted  CarrierDelay  \
# count      0.0  1.311826e+06               0.0  1.311826e+06           0.0
# mean       NaN  1.500580e-02               NaN  2.908160e-03           NaN
# std        NaN  1.215756e-01               NaN  5.384891e-02           NaN
# min        NaN  0.000000e+00               NaN  0.000000e+00           NaN
# 25%        NaN  0.000000e+00               NaN  0.000000e+00           NaN
# 50%        NaN  0.000000e+00               NaN  0.000000e+00           NaN
# 75%        NaN  0.000000e+00               NaN  0.000000e+00           NaN
# max        NaN  1.000000e+00               NaN  1.000000e+00           NaN
#
#        WeatherDelay  NASDelay  SecurityDelay  LateAircraftDelay
# count           0.0       0.0            0.0                0.0
# mean            NaN       NaN            NaN                NaN
# std             NaN       NaN            NaN                NaN
# min             NaN       NaN            NaN                NaN
# 25%             NaN       NaN            NaN                NaN
# 50%             NaN       NaN            NaN                NaN
# 75%             NaN       NaN            NaN                NaN
# max             NaN       NaN            NaN                NaN

# %%
for i in data.columns:
    print(i, data[i].dtype)
# Out:
# Year int64
# Month int64
# DayofMonth int64
# DayOfWeek int64
# DepTime float64
# CRSDepTime int64
# ArrTime float64
# CRSArrTime int64
# UniqueCarrier object
# FlightNum int64
# TailNum float64
# ActualElapsedTime float64
# CRSElapsedTime int64
# AirTime float64
# ArrDelay float64
# DepDelay float64
# Origin object
# Dest object
# Distance float64
# TaxiIn float64
# TaxiOut float64
# Cancelled int64
# CancellationCode float64
# Diverted int64
# CarrierDelay float64
# WeatherDelay float64
# NASDelay float64
# SecurityDelay float64
# LateAircraftDelay float64

# %% [markdown]
# Well well well, those are some big variables to fill.

# %% [markdown]
# Do we need 64 bits to store things like '1987' '12' or '1'?  NO!!!  A simple 8 bit integer will do for many of these columns
# at the very least we can take the first few and make them smaller  but how.  RTFM!!!
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html
#
#     dtype : Type name or dict of column -> type, default None
#
# Data type for data or columns. E.g. {‘a’: np.float64, ‘b’: np.int32} Use str or object to preserve and not interpret dtype. If converters are specified, they will be applied INSTEAD of dtype conversion.
#
# SO I guess we need to apply a dtype argument!

# %%
types={}
for i in data.columns:
    types[i]=data[i].dtype

# %%
types
# Out:
# {'ActualElapsedTime': dtype('float64'),
#  'AirTime': dtype('float64'),
#  'ArrDelay': dtype('float64'),
#  'ArrTime': dtype('float64'),
#  'CRSArrTime': dtype('int64'),
#  'CRSDepTime': dtype('int64'),
#  'CRSElapsedTime': dtype('int64'),
#  'CancellationCode': dtype('float64'),
#  'Cancelled': dtype('int64'),
#  'CarrierDelay': dtype('float64'),
#  'DayOfWeek': dtype('int64'),
#  'DayofMonth': dtype('int64'),
#  'DepDelay': dtype('float64'),
#  'DepTime': dtype('float64'),
#  'Dest': dtype('O'),
#  'Distance': dtype('float64'),
#  'Diverted': dtype('int64'),
#  'FlightNum': dtype('int64'),
#  'LateAircraftDelay': dtype('float64'),
#  'Month': dtype('int64'),
#  'NASDelay': dtype('float64'),
#  'Origin': dtype('O'),
#  'SecurityDelay': dtype('float64'),
#  'TailNum': dtype('float64'),
#  'TaxiIn': dtype('float64'),
#  'TaxiOut': dtype('float64'),
#  'UniqueCarrier': dtype('O'),
#  'WeatherDelay': dtype('float64'),
#  'Year': dtype('int64')}

# %% [markdown]
# I was lazy and made a dictionary.  Now lets go look at what kinda of data types we have
# https://docs.scipy.org/doc/numpy-1.10.0/user/basics.types.html

# %%
types

# %%
types['Year']=np.int8
types['DayOfWeek']=np.int8
types['DayofMonth']=np.int8
types['Month']=np.int8
types['Diverted']=bool
types['CRSDepTime']=np.uint16
types['CRSArrTime']=np.uint16
types['FlightNum']=np.uint16
types['CRSElapsedTime']=np.uint16
types['Cancelled']=np.uint16

# %%
data=pd.read_csv("./Data/1987.csv",dtype=types)

# %%
size_it(data)
# Out:
# 208.93 Megabytes

# %% [markdown]
# What about something like weather delay?  It waas all nan does this hold?

# %%
df=pd.DataFrame()
import os
stuff=os.listdir("./Data")
for i in stuff:
    if ("csv" in i) and ('bz' not in i):
        print(i)
        df=df.append(pd.read_csv("./Data/"+i,usecols=['WeatherDelay']))
# Out:
# 1987.csv
# 1988.csv
# 1989.csv
# 1990.csv
# 1991.csv
# 1992.csv
# 1993.csv
# 1994.csv
# 1995.csv
# 1996.csv
# 1997.csv
# 1998.csv
# 1999.csv
# 2000.csv
# 2001.csv
# 2002.csv
# 2003.csv
# 2004.csv
# 2005.csv
# 2006.csv
# 2007.csv
# 2008.csv
# AirlineDataAll.csv

# %%
df.describe()
# Out:
#        WeatherDelay
# count  3.420554e+07
# mean   7.883406e-01
# std    9.434347e+00
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    0.000000e+00
# max    1.510000e+03

# %% [markdown]
# Ok so this is another timem lets fix that!

# %%
types['WeatherDelay']=np.uint8
data=pd.read_csv("./Data/1987.csv",dtype=types)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-3c21e3559602> in <module>()
#       1 types['WeatherDelay']=np.uint8
# ----> 2 data=pd.read_csv("./Data/1987.csv",dtype=types)
#
# C:\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     707                     skip_blank_lines=skip_blank_lines)
#     708
# --> 709         return _read(filepath_or_buffer, kwds)
#     710
#     711     parser_f.__name__ = name
#
# C:\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     453
#     454     try:
# --> 455         data = parser.read(nrows)
#     456     finally:
#     457         parser.close()
#
# C:\Anaconda3\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1067                 raise ValueError('skipfooter not supported for iteration')
#    1068
# -> 1069         ret = self._engine.read(nrows)
#    1070
#    1071         if self.options.get('as_recarray'):
#
# C:\Anaconda3\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1837     def read(self, nrows=None):
#    1838         try:
# -> 1839             data = self._reader.read(nrows)
#    1840         except StopIteration:
#    1841             if self._first_chunk:
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# ValueError: Integer column has NA values in column 25

# %% [markdown]
# So what went wrong?

# %%
types['WeatherDelay']=np.float16
data=pd.read_csv("./Data/1987.csv",dtype=types)
data['WeatherDelay'].fillna(0,inplace=True)

# %%
data['WeatherDelay']=data['WeatherDelay'].astype(np.uint16)

# %%
size_it(data)
# Out:
# 201.42 Megabytes

# %%
data.iloc[:,0:10].head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0   -61     10          14          3    741.0         730    912.0
# 1   -61     10          15          4    729.0         730    903.0
# 2   -61     10          17          6    741.0         730    918.0
# 3   -61     10          18          7    729.0         730    847.0
# 4   -61     10          19          1    749.0         730    922.0
#
#    CRSArrTime UniqueCarrier  FlightNum
# 0         849            PS       1451
# 1         849            PS       1451
# 2         849            PS       1451
# 3         849            PS       1451
# 4         849            PS       1451

# %%
data.iloc[:,10:20].head()
# Out:
#    TailNum  ActualElapsedTime  CRSElapsedTime  AirTime  ArrDelay  DepDelay  \
# 0      NaN               91.0              79      NaN      23.0      11.0
# 1      NaN               94.0              79      NaN      14.0      -1.0
# 2      NaN               97.0              79      NaN      29.0      11.0
# 3      NaN               78.0              79      NaN      -2.0      -1.0
# 4      NaN               93.0              79      NaN      33.0      19.0
#
#   Origin Dest  Distance  TaxiIn
# 0    SAN  SFO     447.0     NaN
# 1    SAN  SFO     447.0     NaN
# 2    SAN  SFO     447.0     NaN
# 3    SAN  SFO     447.0     NaN
# 4    SAN  SFO     447.0     NaN

# %%
data=pd.read_csv('HIGGS.csv/HIGGS.csv',nrows=2E6,header=None)

# %%
size_it(data)
# Out:
# 457.76 Megabytes

# %%
data.columns=['label','lepton pT', 'lepton eta', 'lepton phi', 'missing energy magnitude', 'missing energy phi', 'jet 1 pt',
             'jet 1 eta', 'jet 1 phi', 'jet 1 b-tag', 'jet 2 pt', 'jet 2 eta', 'jet 2 phi', 'jet 2 b-tag', 'jet 3 pt',
             'jet 3 eta', 'jet 3 phi', 'jet 3 b-tag', 'jet 4 pt', 'jet 4 eta', 'jet 4 phi', 'jet 4 b-tag', 'm_jj',
             'm_jjj', 'm_lv','m_jlv', 'm_bb', 'm_wbb', 'm_wwbb']

# %%
data.describe()
# Out:
#               label     lepton pT    lepton eta    lepton phi  \
# count  2.000000e+06  2.000000e+06  2.000000e+06  2.000000e+06
# mean   5.294090e-01  9.909598e-01  3.508929e-04 -9.774250e-05
# std    4.991345e-01  5.649717e-01  1.008749e+00  1.006160e+00
# min    0.000000e+00  2.746966e-01 -2.434976e+00 -1.742508e+00
# 25%    0.000000e+00  5.902043e-01 -7.373486e-01 -8.719308e-01
# 50%    1.000000e+00  8.530054e-01 -5.415563e-05  4.165800e-04
# 75%    1.000000e+00  1.235860e+00  7.382142e-01  8.704391e-01
# max    1.000000e+00  9.112755e+00  2.434868e+00  1.743236e+00
#
#        missing energy magnitude  missing energy phi      jet 1 pt  \
# count              2.000000e+06        2.000000e+06  2.000000e+06
# mean               9.981952e-01       -8.797682e-04  9.903717e-01
# std                5.996122e-01        1.006321e+00  4.743143e-01
# min                6.259872e-04       -1.743944e+00  1.378689e-01
# 25%                5.765781e-01       -8.717076e-01  6.791759e-01
# 50%                8.912961e-01       -1.173775e-03  8.942697e-01
# 75%                1.292381e+00        8.706231e-01  1.170282e+00
# max                1.130734e+01        1.743257e+00  8.382610e+00
#
#           jet 1 eta     jet 1 phi   jet 1 b-tag      ...          jet 4 eta  \
# count  2.000000e+06  2.000000e+06  2.000000e+06      ...       2.000000e+06
# mean  -5.543756e-04  8.564739e-04  1.001532e+00      ...      -4.719628e-04
# std    1.009418e+00  1.005991e+00  1.027880e+00      ...       1.007982e+00
# min   -2.969725e+00 -1.741237e+00  0.000000e+00      ...      -2.497265e+00
# 25%   -6.872450e-01 -8.664331e-01  0.000000e+00      ...      -7.150230e-01
# 50%   -1.015666e-03  1.269625e-03  1.086538e+00      ...      -4.606903e-04
# 75%    6.871941e-01  8.694214e-01  2.173076e+00      ...       7.141017e-01
# max    2.969674e+00  1.741454e+00  2.173076e+00      ...       2.498009e+00
#
#           jet 4 phi   jet 4 b-tag          m_jj         m_jjj          m_lv  \
# count  2.000000e+06  2.000000e+06  2.000000e+06  2.000000e+06  2.000000e+06
# mean  -5.396924e-04  9.982941e-01  1.034310e+00  1.024758e+00  1.050398e+00
# std    1.006413e+00  1.399433e+00  6.731967e-01  3.800105e-01  1.640799e-01
# min   -1.742691e+00  0.000000e+00  9.117591e-02  2.347527e-01  8.304866e-02
# 25%   -8.720338e-01  0.000000e+00  7.907383e-01  8.462544e-01  9.857500e-01
# 50%   -1.929117e-03  0.000000e+00  8.949145e-01  9.506407e-01  9.897675e-01
# 75%    8.710505e-01  3.101961e+00  1.024475e+00  1.083482e+00  1.020230e+00
# max    1.743372e+00  3.101961e+00  3.107619e+01  1.563786e+01  5.921233e+00
#
#               m_jlv          m_bb         m_wbb        m_wwbb
# count  2.000000e+06  2.000000e+06  2.000000e+06  2.000000e+06
# mean   1.009770e+00  9.731415e-01  1.033149e+00  9.598571e-01
# std    3.975953e-01  5.249465e-01  3.649597e-01  3.132275e-01
# min    1.574726e-01  4.812501e-02  3.033497e-01  3.307214e-01
# 25%    7.674656e-01  6.741834e-01  8.195511e-01  7.704058e-01
# 50%    9.164187e-01  8.735141e-01  9.474310e-01  8.718997e-01
# 75%    1.142067e+00  1.139176e+00  1.140899e+00  1.059294e+00
# max    1.079409e+01  1.373569e+01  8.779915e+00  6.292962e+00
#
# [8 rows x 29 columns]

# %%
# %matplotlib inline
plt.rcParams['figure.max_open_warning']=40
colnames=list(data.columns.values)
for i in colnames[1:]:
        facet = sns.FacetGrid(data, hue='label',aspect=2)
        facet.map(sns.kdeplot,i,shade= False)
        facet.add_legend()
        plt.show()

# %%
plt.rcParams['figure.max_open_warning']=40
colnames=list(data.columns.values)
for i in colnames[1:]:
        facet = sns.FacetGrid(data, hue='label',aspect=2)
        facet.map(sns.distplot,i)
        facet.add_legend()
        plt.show()

# %%
colnames=list(data.columns.values)
for i in colnames[2:]:
        facet = sns.FacetGrid(data,aspect=2)
        facet.map(sns.violinplot,x=data[0],y=data[i],hue=data[0],split=True)
        facet.add_legend()
        plt.show()

# %%
ax=sns.violinplot(y=data['lepton phi'],hue=data['label'],x=data['label'],split=True)
plt.show()

# %%
sns.heatmap(data.corr(),cmap="YlGnBu")
plt.show()

# %%
from sklearn.linear_model import SGDClassifier
clf = SGDClassifier(loss="log", penalty="l2",max_iter=20)

# %%
n=1000000
val_x=data.iloc[n:,1:]
val_y=data.iloc[n:,0]
X=data.iloc[0:n,1:]
y=data.iloc[0:n,0]
clf.fit(X,y)
# Out:
# SGDClassifier(alpha=0.0001, average=False, class_weight=None, epsilon=0.1,
#        eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='log', max_iter=20, n_iter=None,
#        n_jobs=1, penalty='l2', power_t=0.5, random_state=None,
#        shuffle=True, tol=None, verbose=0, warm_start=False)

# %%
x=clf.predict_proba(val_x)

# %%
from sklearn.metrics import accuracy_score, roc_curve,auc,roc_auc_score
accuracy_score(val_y,clf.predict(val_x))
# Out:
# 0.639001

# %%
data.shape[0]/1E6

# %%
fpr, tpr, _ = roc_curve(val_y, x[:,1])
roc_auc = auc(fpr, tpr)

# %%
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()

# %%
chunksize = 10 ** 6
clf = SGDClassifier(loss="log", penalty="l2",max_iter=1)
for i in range(4):
    for chunk in pd.read_csv('HIGGS.csv/HIGGS.csv',header=None,chunksize=chunksize):
        X=chunk.iloc[:,1:]
        y=chunk.iloc[:,0]
        clf.partial_fit(X,y,classes=[0,1])
        print(roc_auc_score(val_y,clf.predict(val_x)),"\t",time.time())
# Out:
# 0.5786517415276956 	 1522379639.6613767
# 0.6263069008209157 	 1522379653.684734
# 0.6252129139453433 	 1522379667.283308
# 0.6291844884096156 	 1522379680.775815
# 0.6342300764356503 	 1522379694.321359
# 0.6329688980293849 	 1522379708.1515875
# 0.6135540646420874 	 1522379722.28702
# 0.6328394985657086 	 1522379735.9786623
# 0.6334431315640948 	 1522379749.8234005
# 0.632895005061467 	 1522379763.2993975
# 0.633331221002884 	 1522379776.945003
# 0.6292010723472602 	 1522379790.478534
# 0.6277144493123469 	 1522379804.4423518
# 0.6348693472113713 	 1522379817.9233472
# 0.63427168840163 	 1522379831.3057775
# 0.6338619681352065 	 1522379844.7532547
# 0.6272552284565779 	 1522379858.3208206
# 0.6326623950969847 	 1522379872.1180277
# 0.6350838215660551 	 1522379885.9387503
# 0.6337294071495507 	 1522379899.544329
# 0.634836949663442 	 1522379913.3965719
# 0.6345328668840541 	 1522379927.0992293
# 0.6313408802842571 	 1522379940.5662158
# 0.6336930855287042 	 1522379954.9618218
# 0.63140049448687 	 1522379968.451323
# 0.6319666807816888 	 1522379982.003873
# 0.6298846456407134 	 1522379995.5053828
# 0.6346836425180593 	 1522380009.4021602
# 0.6356636869386062 	 1522380023.4090064
# 0.6346586126635194 	 1522380038.3719912
# 0.6357222524982195 	 1522380053.1963832
# 0.6339969552240915 	 1522380067.836658
# 0.6343383410790382 	 1522380082.559983
# 0.6354889190053875 	 1522380096.9030538
# 0.6346898742417371 	 1522380115.4244132
# 0.632564673415673 	 1522380129.4607787
# 0.6355298971277414 	 1522380143.1694314
# 0.6313985007727796 	 1522380156.9956572
# 0.6354516579124743 	 1522380170.4116101
# 0.6330458849798017 	 1522380183.8605838
# 0.633535314616674 	 1522380197.875936
# 0.6350957531563068 	 1522380213.1121082
# 0.6347935151549657 	 1522380227.71436
# 0.6348406931226835 	 1522380241.1753473

# %%
import time

# %%
print(time.time())

# %%
SGDClassifier.__class__
